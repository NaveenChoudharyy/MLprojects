# %% [markdown]
# # Movies Recommendation system

# %%
# Importing required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Importing given datasets

movies = pd.read_csv("C:/Users/navee/OneDrive/Desktop/GitHub/MLprojects/Movies_recommendation_system/Data/movies.csv")
credits = pd.read_csv("C:/Users/navee/OneDrive/Desktop/GitHub/MLprojects/Movies_recommendation_system/Data/credits.csv")

# %% [markdown]
# ### Movies

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.duplicated().sum()

# No duplicates found
# Out:
# 0

# %%
# Info about movies table

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# ###### For creating movies recommendation system we need to find the similarity between the movies, so we required only those variables which can provide any information if that movie is similar with another ovie or not.

# %%
movies = movies[['genres', 'id', 'keywords', 'original_title', 'overview', 'spoken_languages', 'tagline', 'title']]

movies.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movies.isna().sum()

# We need null value tratment as there are some missings
# Out:
# genres                0
# id                    0
# keywords              0
# original_title        0
# overview              3
# spoken_languages      0
# tagline             844
# title                 0
# dtype: int64

# %%
# We need to drop the records where overview is itself missing as it contains lots of information 
# about the sismilarity of the movie which cannot be treated or replaced.

# Whereever "tagline" is missing we can replace null with blank ("") as it doesnot contain that much information
# and this will avoid the information loss also.


movies = movies.dropna(subset="overview")

movies = movies.fillna(value="")

movies.isna().sum()
# Out:
# genres              0
# id                  0
# keywords            0
# original_title      0
# overview            0
# spoken_languages    0
# tagline             0
# title               0
# dtype: int64

# %%
import json

# %%
# Extracting required information from variable "genres"

movies.genres.apply( lambda x: json.loads(x) )[1]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 28, 'name': 'Action'}]

# %%
# From variable gerne we need only "name"

movies.genres = movies.genres.apply( lambda x: [genres['name'] for genres in eval(x)])


movies.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
# Likewise we have to do this for all columns


# Extracting required information from variable "genres"

json.loads(movies.loc[1, 'keywords'])
# Out:
# [{'id': 270, 'name': 'ocean'},
#  {'id': 726, 'name': 'drug abuse'},
#  {'id': 911, 'name': 'exotic island'},
#  {'id': 1319, 'name': 'east india trading company'},
#  {'id': 2038, 'name': "love of one's life"},
#  {'id': 2052, 'name': 'traitor'},
#  {'id': 2580, 'name': 'shipwreck'},
#  {'id': 2660, 'name': 'strong woman'},
#  {'id': 3799, 'name': 'ship'},
#  {'id': 5740, 'name': 'alliance'},
#  {'id': 5941, 'name': 'calypso'},
#  {'id': 6155, 'name': 'afterlife'},
#  {'id': 6211, 'name': 'fighter'},
#  {'id': 12988, 'name': 'pirate'},
#  {'id': 157186, 'name': 'swashbuckler'},
#  {'id': 179430, 'name': 'aftercreditsstinger'}]

# %%
movies.keywords = movies.keywords.apply( lambda x: [keywords['name'] for keywords in eval(x)] )


movies.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
# Extracting required information from variable "spoken_languages"


movies.loc[1, 'spoken_languages']
# Out:
# '[{"iso_639_1": "en", "name": "English"}]'

# %%
movies.spoken_languages = movies.spoken_languages.apply( lambda x: 
                                                        [spoken_languages['name'] for spoken_languages in eval(x)] )


movies.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %% [markdown]
# ### Credits

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.info()

# No nulls available
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
credits.duplicated().sum()


# No duplicate found
# Out:
# 0

# %%
# Extracting required information from variable "cast"


json.loads(credits.loc[1, 'cast'])

# Here, we need to extract both "character" and "name"
# Out:
# [{'cast_id': 4,
#   'character': 'Captain Jack Sparrow',
#   'credit_id': '52fe4232c3a36847f800b50d',
#   'gender': 2,
#   'id': 85,
#   'name': 'Johnny Depp',
#   'order': 0},
#  {'cast_id': 5,
#   'character': 'Will Turner',
#   'credit_id': '52fe4232c3a36847f800b511',
#   'gender': 2,
#   'id': 114,
#   'name': 'Orlando Bloom',
#   'order': 1},
#  {'cast_id': 6,
#   'character': 'Elizabeth Swann',
#   'credit_id': '52fe4232c3a36847f800b515',
#   'gender': 1,
#   'id': 116,
#   'name': 'Keira Knightley',
#   'order': 2},
#  {'cast_id': 12,
#   'character': 'William "Bootstrap Bill" Turner',
#   'credit_id': '52fe4232c3a36847f800b52d',
#   'gender': 2,
#   'id': 1640,
#   'name': 'Stellan Skarsgård',
#   'order': 3},
#  {'cast_id': 10,
#   'character': 'Captain Sao Feng',
#   'credit_id': '52fe4232c3a36847f800b525',
#   'gender': 2,
#   'id': 1619,
#   'name': 'Chow Yun-fat',
#   'order': 4},
#  {'cast_id': 9,
#   'character': 'Captain Davy Jones',
# ...

# %%
credits.cast = credits.cast.apply( lambda x: [cast['character'] for cast in 
                                              eval(x)]) + credits.cast.apply( lambda x: 
                                                                             [cast['name'] for cast in eval(x)])


credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...
# 2  [James Bond, Blofeld, Madeleine, M, Lucia, Q, ...
# 3  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# 4  [John Carter, Dejah Thoris, Sola, Tars Tarkas,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
# Extracting required information from variable "crew"


json.loads(credits.loc[1, 'crew'])


# Here, we need only name to be extracted
# Out:
# [{'credit_id': '52fe4232c3a36847f800b579',
#   'department': 'Camera',
#   'gender': 2,
#   'id': 120,
#   'job': 'Director of Photography',
#   'name': 'Dariusz Wolski'},
#  {'credit_id': '52fe4232c3a36847f800b4fd',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 1704,
#   'job': 'Director',
#   'name': 'Gore Verbinski'},
#  {'credit_id': '52fe4232c3a36847f800b54f',
#   'department': 'Production',
#   'gender': 2,
#   'id': 770,
#   'job': 'Producer',
#   'name': 'Jerry Bruckheimer'},
#  {'credit_id': '52fe4232c3a36847f800b503',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 1705,
#   'job': 'Screenplay',
#   'name': 'Ted Elliott'},
#  {'credit_id': '52fe4232c3a36847f800b509',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 1706,
#   'job': 'Screenplay',
#   'name': 'Terry Rossio'},
#  {'credit_id': '52fe4232c3a36847f800b57f',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
# ...

# %%
credits.crew = credits.crew.apply( lambda x: [crew['name'] for crew in eval(x)] )


credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...
# 2  [James Bond, Blofeld, Madeleine, M, Lucia, Q, ...
# 3  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# 4  [John Carter, Dejah Thoris, Sola, Tars Tarkas,...
#
#                                                 crew
# 0  [Stephen E. Rivkin, Rick Carter, Christopher B...
# 1  [Dariusz Wolski, Gore Verbinski, Jerry Bruckhe...
# 2  [Thomas Newman, Sam Mendes, Anna Pinnock, John...
# 3  [Hans Zimmer, Charles Roven, Christopher Nolan...
# ...

# %%
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [Jake Sully, Neytiri, Dr. Grace Augustine, Col...
# 1     [Captain Jack Sparrow, Will Turner, Elizabeth ...
# 2     [James Bond, Blofeld, Madeleine, M, Lucia, Q, ...
# ...

# %%
# Mergeing both the datasets


df = pd.merge(left=movies, right=credits, left_on=['id', 'title'], right_on=['movie_id', 'title'], how='inner')

# %%
df
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4794                      [Action, Crime, Thriller]    9367
# 4795                              [Comedy, Romance]   72766
# 4796             [Comedy, Drama, Romance, TV Movie]  231617
# 4797                                             []  126186
# 4798                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4799 entries, 0 to 4798
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            4799 non-null   object
#  1   id                4799 non-null   int64
#  2   keywords          4799 non-null   object
#  3   original_title    4799 non-null   object
#  4   overview          4799 non-null   object
#  5   spoken_languages  4799 non-null   object
#  6   tagline           4799 non-null   object
#  7   title             4799 non-null   object
#  8   movie_id          4799 non-null   int64
#  9   cast              4799 non-null   object
#  10  crew              4799 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 412.5+ KB

# %%
import re

# %%
# Tokenization for variable "overview"

df['overview'] = df['overview'].apply(lambda x: re.split(r'[ :`~#!@$%\^&*()\[\]{}\-_+=;\"<,.>/?|]', x))

df['tagline'] = df['tagline'].apply(lambda x: re.split(r'[ :`~#!@$%\^&*()\[\]{}\-_+=;\"<,.>/?|]', x))

# %%
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from wordcloud import STOPWORDS

stp_words = list(set(list(ENGLISH_STOP_WORDS) + list(STOPWORDS)))

# %%
# Removing stopwords, single charaters and panctuations

df['overview'] = df.overview.apply( lambda x: [w for w in x if 
                                               len(w) > 1 and 
                                               w not in stp_words and 
                                               w not in string.punctuation] )


df['tagline'] = df.tagline.apply( lambda x: [w for w in x if 
                                               len(w) > 1 and 
                                               w not in stp_words and 
                                               w not in string.punctuation] )

# %%
df = df[['movie_id', 'title', 'overview', 'tagline', 'genres', 'keywords', 'spoken_languages', 'cast', 'crew']]

# %%
df['merged_col_1'] = df.overview + df.tagline + df.keywords


df = df.drop(columns=['overview' , 'tagline' , 'keywords'])


df.head()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_6204\4061799950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['merged_col_1'] = df.overview + df.tagline + df.keywords
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# ...

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
from textblob import TextBlob

# %%
df.merged_col_1 = df.merged_col_1.apply( lambda x: " ".join(x))


df.merged_col_1 = df.merged_col_1.apply( lambda x: WordNetLemmatizer().lemmatize(x) )


df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                   spoken_languages  \
# 0                               [English, Español]
# 1                                        [English]
# 2  [Français, English, Español, Italiano, Deutsch]
# 3                                        [English]
# 4                                        [English]
#
# ...

# %%
df['merged_col_2'] = df.genres + df.spoken_languages + df.cast + df.crew

df.merged_col_2 = df.merged_col_2.apply( lambda x: " ".join(x))

df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                   spoken_languages  \
# 0                               [English, Español]
# 1                                        [English]
# 2  [Français, English, Español, Italiano, Deutsch]
# 3                                        [English]
# 4                                        [English]
#
# ...

# %%
df = df.drop(columns=['genres','spoken_languages','cast','crew'])

df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                         merged_col_1  \
# 0  In 22nd century paraplegic Marine dispatched m...
# 1  Captain Barbossa long believed dead come life ...
# 2  cryptic message Bond’s past sends trail uncove...
# 3  Following death District Attorney Harvey Dent ...
# 4  John Carter war weary military captain inexpli...
#
#                                         merged_col_2
# 0  Action Adventure Fantasy Science Fiction Engli...
# 1  Adventure Fantasy Action English Captain Jack ...
# 2  Action Adventure Crime Français English Españo...
# 3  Action Crime Drama Thriller English Bruce Wayn...
# ...

# %%
df['merged_col'] = df.merged_col_1 

df = df.drop(columns=['merged_col_1', 'merged_col_2'])

df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           merged_col
# 0  In 22nd century paraplegic Marine dispatched m...
# 1  Captain Barbossa long believed dead come life ...
# 2  cryptic message Bond’s past sends trail uncove...
# 3  Following death District Attorney Harvey Dent ...
# 4  John Carter war weary military captain inexpli...

# %% [markdown]
# # Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv = CountVectorizer(token_pattern=r'\b[a-zA-Z]+\b', max_features=5000)

# %%
X = cv.fit_transform(df.merged_col)

# %%
from sklearn.metrics.pairwise import cosine_similarity

X = cosine_similarity(X)

# %%
X
# Out:
# array([[1.        , 0.03563483, 0.        , ..., 0.03414939, 0.01690309,
#         0.        ],
#        [0.03563483, 1.        , 0.04348854, ..., 0.08518354, 0.02108185,
#         0.04259177],
#        [0.        , 0.04348854, 1.        , ..., 0.02083786, 0.        ,
#         0.04167571],
#        ...,
#        [0.03414939, 0.08518354, 0.02083786, ..., 1.        , 0.0404061 ,
#         0.04081633],
#        [0.01690309, 0.02108185, 0.        , ..., 0.0404061 , 1.        ,
#         0.06060915],
#        [0.        , 0.04259177, 0.04167571, ..., 0.04081633, 0.06060915,
#         1.        ]])

# %%
def recommend_movie(movie):
    movie_index = df[df['title'] == movie].index[0]
    distances = X[movie_index]
    movie_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]
    
    for i in movie_list:
        print(df.iloc[i[0]].title)

# %%
list(movies.title)
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
#  'Transformers: Revenge of the Fallen',
# ...

# %%
recommend_movie ('Superman Returns')
# Out:
# Superman II
# Superman
# Superman III
# Man of Steel
# Superman IV: The Quest for Peace
